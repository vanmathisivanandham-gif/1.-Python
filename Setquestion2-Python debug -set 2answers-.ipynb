# %%
#1.Find the error in the following Python code:
import math
print(Math.sqrt(16))

# %%
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
#2.Find the error in the following Python code:

def my_function():
    x += 5
    print(x)

x = 10
my_function()

# %%
def my_function():
    x = 10
    x += 5
    
    print(x)
my_function()
# Out:
# 15

# %%
#3.x = 5
if (x = 10):
    print("x is 10")
    
#assignment operator is missing in if statement, x=5 is commented and not declared

# %%
if (x == 10):
    print("x is 10")
# Out:
# x is 10

# %% [markdown]
# #4.
# numbers = [5, 3, 8, 2]
# print(numbers.sort())

# %%
numbers = [5, 3, 8, 2]
numbers.sort()
print(numbers)
# Out:
# [2, 3, 5, 8]

# %% [markdown]
# #5.
# def square(n):
#     n * n
#     square(n)
#     print(square(4))

# %%
def square(n):
    return n*n
print(square(4))
# Out:
# 16

# %% [markdown]
# #6.
# my_tuple = (1, 2, 3)
# my_tuple[1] = 5

# %%
my_tuple = (1, 2, 3)
my_list=list(my_tuple)
my_list[1] = (5)
my_tuple=tuple(my_list)
print (my_tuple)
# Out:
# (1, 5, 3)

# %% [markdown]
# #7.
# name = "Alice"
# age = 25
# print("My name is %s and I am %d years old" % (name))

# %%
name = "Alice"
age = 25
print("My name is %s and I am %d years old" % (name,age))
# Out:
# My name is Alice and I am 25 years old

# %% [markdown]
# #8.
# a = [1, 2, 3]
# b = [1, 2, 3]
# if a is b:
#     print("Lists are equal")

# %%
#8.
a = [1, 2, 3]
b = [1, 2, 3]
if a == b:
    print("Lists are equal")
# Out:
# Lists are equal

# %%
#9.
for i in range(5, -1):
    print(i)

# %%
for i in range(5, -1, -1):
    print(i)
# Out:
# 5
# 4
# 3
# 2
# 1
# 0

# %% [markdown]
# #10.
# student = {"name": "John", "age": 20}
# print(student(name))

# %%
student = {"fullname": "John", "age": 20}
print(student["fullname"])
# Out:
# John
