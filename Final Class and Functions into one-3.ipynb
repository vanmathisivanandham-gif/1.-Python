# %%
from Groupoffunctionsinclass2 import multiplefunctions

# %%
multiplefunctions.oddeven()
# Out:
# Enter a number: 33
# 33 is Odd number
# 'odd number'

# %%
multiplefunctions.Eligible1()
# Out:
# Your Gender: Female
# Your Age: 19
# Eligible
# 'Eligible'
