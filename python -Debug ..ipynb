# %%
#1.Find the error in the following Python code:

for i in range(5):
     print(i)

#colon is missing and indent of print and for are incorrect
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#2.What will be the output of this code?

a = 10
b = 5
print(a + b)
#"5" is a integer and not a string, so it doesn't need double quotes
# Out:
# 15

# %%
#3.What is the issue in this Python snippet?

def add_numbers(a, b):
    return a + b
#remove the space before the def and colon is missing in function syntax
#variables are not defined and not called the function to get the output

# %%
#4.Identify the bug in the following Python code:

numbers = [1, 2, 3, 4,5]
print(numbers[4])
#in the listed numbers, we dont have 5th index so getting error, it calculates from 0,1,2,3,
#if numbers = [1,2,3,4,5] then it will print 5
# Out:
# 5

# %%
#5.Find the error in the following Python code:
print ("Hello, World!")
#missing brackets for print
# Out:
# Hello, World!

# %%
#6.Find the error in the following Python code:
x = 5 / 0
#any number cannot be divided by 0

# %%
#7.Find the error in the following Python code:
name = "Alice"
age = 25
print("Name: " + name + ", , Age: " + age)
#print statement is incorrect. adding string and integer is not possible

# %%
#8.Find the error
for i in range(1, 10, -1):
    print(i)
#range rules are start, stop, step, but the start and stop positions are having 1 and 10, which is increasing positively, so if -1 applies in range 
    #it should go down so there is no possibility to apply -1 in range 1, 10

# %%
#9. Find the error in the following Python code:
x = 10
if x = 5:
    print("x is 5")

#assignment operator is missing in if statement
# also after adding assignment operator it will be run but will not give any output as the x value is declared as 10 in the program

# %%
#10. Identify the error in the following function definition:

def greet(name)
    print("Hello, " + name)
    
#Colon is missing in function syntax
#return statement is missing 
#did not call the function to get the output
